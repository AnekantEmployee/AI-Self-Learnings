# %%
import os

# %%
# !pip install langchain_huggingface langchain dotenv

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
