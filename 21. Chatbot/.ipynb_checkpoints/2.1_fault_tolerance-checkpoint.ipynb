# %%
# !pip install langgraph
# Out:
# Requirement already satisfied: langgraph in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (0.6.2)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (0.3.69)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (0.6.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (0.2.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph) (0.4.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\anekant.jain\appdata\roaming\python\python311\site-packages (from langchain-core>=0.1->langgraph) (4.13.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\anekant.jain\appdata\roaming\python\python311\site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (3.11.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: anyio in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (4.9.0)
# Requirement already satisfied: certifi in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\anekant.jain\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.0->langgraph) (1.3.1)
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    config = {"configurable": {"thread_id": 'thread-1'}}
    graph.invoke({"input": "start"}, config=config)
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
graph.get_state(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 graph.get_state(config)
#
# NameError: name 'graph' is not defined
