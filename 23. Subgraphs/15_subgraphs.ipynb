# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
class SubState(TypedDict):

    input_text: str
    translated_text: str

# %%
subgraph_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
def translate_text(state: SubState):

    prompt = f"""
Translate the following text to Hindi.
Keep it natural and clear. Do not add extra content.

Text:
{state["input_text"]}
""".strip()
    
    translated_text = subgraph_llm.invoke(prompt).content

    return {'translated_text': translated_text}

# %%
subgraph_builder = StateGraph(SubState)

subgraph_builder.add_node('translate_text', translate_text)

subgraph_builder.add_edge(START, 'translate_text')
subgraph_builder.add_edge('translate_text', END)

subgraph = subgraph_builder.compile()

# %%
class ParentState(TypedDict):

    question: str
    answer_eng: str
    answer_hin: str

# %%
parent_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
def generate_answer(state: ParentState):

    answer = parent_llm.invoke(f"You are a helpful assistant. Answer clearly.\n\nQuestion: {state['question']}").content
    return {'answer_eng': answer}

# %%
def translate_answer(state: ParentState):

    # call the subgraph
    result = subgraph.invoke({'input_text': state['answer_eng']})

    return {'answer_hin': result['translated_text']}

# %%
parent_builder = StateGraph(ParentState)

parent_builder.add_node("answer", generate_answer)
parent_builder.add_node("translate", translate_answer)

parent_builder.add_edge(START, 'answer')
parent_builder.add_edge('answer', 'translate')
parent_builder.add_edge('translate', END)

# %%
graph = parent_builder.compile()

graph

# %%
graph.invoke({'question': 'What is quantum physics'})
# Out:
# {'question': 'What is quantum physics',
#  'answer_eng': 'Quantum physics (also known as quantum mechanics or quantum theory) is **the branch of physics that studies the behavior of matter and energy at the atomic and subatomic level.**\n\nIt\'s fundamentally different from classical physics (which describes the world at larger scales) because the rules that govern everyday objects break down when you go incredibly small.\n\nHere\'s a breakdown of what that means:\n\n1.  **The World of the Very Small:** Quantum physics deals with particles like electrons, protons, neutrons, photons (light particles), and even smaller, more exotic particles.\n\n2.  **Classical Rules Don\'t Apply:**\n    *   **Classical physics** assumes things are continuous and predictable. If you throw a ball, you can predict its exact path and where it will land.\n    *   **Quantum physics** reveals a universe that is discrete, probabilistic, and often counter-intuitive at its core.\n\n3.  **Key Concepts of Quantum Physics:**\n\n    *   **Quantization:** This is where the "quantum" comes from. Energy, momentum, and other properties don\'t exist in a continuous range but rather in discrete, indivisible packets called "quanta." Think of it like a staircase instead of a ramp – you can only be on specific steps, not anywhere in between.\n    *   **Wave-Particle Duality:** Particles like electrons and photons can exhibit both wave-like and particle-like properties. Light, for example, can act as a wave (explaining diffraction) and as a particle (photons, explaining the photoelectric effect).\n    *   **Superposition:** A quantum particle can exist in multiple states simultaneously until it is observed or measured. For example, an electron can be spinning both clockwise and counter-clockwise at the same time until its spin is measured.\n    *   **Entanglement:** Two or more quantum particles can become linked in such a way that they share the same fate, no matter how far apart they are. Measuring a property of one instantaneously affects the state of the other, even across vast distances ("spooky action at a distance," as Einstein called it).\n    *   **Uncertainty Principle (Heisenberg\'s):** You cannot simultaneously know with perfect precision certain pairs of properties of a particle, such as its exact position and its exact momentum. The more precisely you know one, the less precisely you can know the other.\n    *   **Probability:** Unlike classical physics, where outcomes are deterministic, quantum physics often describes the probability of various outcomes. We can\'t always predict exactly what will happen, only the likelihood of different possibilities.\n\n**Why is it important?**\n\nDespite its "weirdness," quantum physics is one of the most successful theories in science. It has allowed us to:\n*   Understand the structure of atoms and molecules.\n*   Develop technologies like lasers, transistors (the basis of all modern electronics), MRI scanners, LEDs, and atomic clocks.\n*   Explore new frontiers like quantum computing and quantum cryptography.\n\nIn essence, quantum physics provides the fundamental framework for understanding how the universe works at its most basic level, underpinning almost all of modern technology and our understanding of chemistry, materials science, and even cosmology.',
#  'answer_hin': '**क्वांटम भौतिकी (जिसे क्वांटम यांत्रिकी या क्वांटम सिद्धांत के नाम से भी जाना जाता है) भौतिकी की वह शाखा है जो परमाणु और उप-परमाणु स्तर पर पदार्थ और ऊर्जा के व्यवहार का अध्ययन करती है।**\n\nयह शास्त्रीय भौतिकी (जो बड़े पैमाने पर दुनिया का वर्णन करती है) से मौलिक रूप से भिन्न है, क्योंकि जब आप अविश्वसनीय रूप से छोटे पैमाने पर जाते हैं तो रोज़मर्रा की वस्तुओं को नियंत्रित करने वाले नियम लागू नहीं होते।\n\nइसका क्या अर्थ है, इसका विवरण नीचे दिया गया है:\n\n1.  **बहुत छोटे का संसार:** क्वांटम भौतिकी इलेक्ट्रॉन, प्रोटॉन, न्यूट्रॉन, फोटॉन (प्रकाश कण), और इससे भी छोटे, अधिक विदेशी कणों जैसे कणों से संबंधित है।\n\n2.  **शास्त्रीय नियम लागू नहीं होते:**\n    *   **शास्त्रीय भौतिकी** यह मानती है कि चीजें निरंतर और अनुमानित होती हैं। यदि आप एक गेंद फेंकते हैं, तो आप उसके सटीक मार्ग और वह कहाँ गिरेगी, इसकी भविष्यवाणी कर सकते हैं।\n    *   **क्वांटम भौतिकी** एक ऐसे ब्रह्मांड को उजागर करती है जो अपने मूल में असतत (discrete), संभाव्य (probabilistic) और अक्सर सहज ज्ञान के विपरीत (counter-intuitive) होता है।\n\n3.  **क्वांटम भौतिकी की मुख्य अवधारणाएँ:**\n\n    *   **प्रमात्रीकरण (Quantization):** "क्वांटम" शब्द यहीं से आया है। ऊर्जा, संवेग और अन्य गुण एक सतत सीमा में मौजूद नहीं होते, बल्कि "क्वांटा" नामक असतत, अविभाज्य पैकेटों में होते हैं। इसे एक रैंप के बजाय सीढ़ी की तरह सोचें – आप केवल विशिष्ट सीढ़ियों पर ही हो सकते हैं, बीच में कहीं नहीं।\n    *   **तरंग-कण द्वैतता (Wave-Particle Duality):** इलेक्ट्रॉन और फोटॉन जैसे कण तरंग-जैसे और कण-जैसे दोनों गुण प्रदर्शित कर सकते हैं। उदाहरण के लिए, प्रकाश एक तरंग के रूप में कार्य कर सकता है (विवर्तन की व्याख्या करता है) और एक कण के रूप में (फोटॉन, प्रकाशविद्युत प्रभाव की व्याख्या करता है)।\n    *   **अध्यारोपण (Superposition):** एक क्वांटम कण एक साथ कई अवस्थाओं में मौजूद हो सकता है जब तक उसे देखा या मापा नहीं जाता। उदाहरण के लिए, एक इलेक्ट्रॉन एक ही समय में दक्षिणावर्त और वामावर्त दोनों दिशाओं में घूम सकता है जब तक कि उसके स्पिन को मापा न जाए।\n    *   **उलझाव (Entanglement):** दो या दो से अधिक क्वांटम कण इस तरह से जुड़ सकते हैं कि वे एक ही नियति साझा करते हैं, चाहे वे कितनी भी दूर क्यों न हों। एक के गुण को मापने से दूसरे की अवस्था तुरंत प्रभावित होती है, यहां तक कि विशाल दूरियों पर भी (जैसा कि आइंस्टीन ने इसे "दूर से डरावनी क्रिया" कहा था)।\n    *   **अनिश्चितता सिद्धांत (हाइजेनबर्ग का - Uncertainty Principle):** आप एक कण के गुणों के कुछ युग्मों को एक साथ पूर्ण सटीकता के साथ नहीं जान सकते, जैसे उसकी सटीक स्थिति और उसका सटीक संवेग। आप एक को जितनी अधिक सटीकता से जानेंगे, दूसरे को उतनी ही कम सटीकता से जान पाएंगे।\n    *   **प्रायिकता (Probability):** शास्त्रीय भौतिकी के विपरीत, जहाँ परिणाम नियतात्मक होते हैं, क्वांटम भौतिकी अक्सर विभिन्न परिणामों की प्रायिकता का वर्णन करती है। हम हमेशा यह अनुमान नहीं लगा सकते कि वास्तव में क्या होगा, केवल विभिन्न संभावनाओं की संभाव्यता।\n\n**यह महत्वपूर्ण क्यों है?**\n\nअपनी "अजीबोगरीब" प्रकृति के बावजूद, क्वांटम भौतिकी विज्ञान के सबसे सफल सिद्धांतों में से एक है। इसने हमें सक्षम बनाया है:\n*   परमाणुओं और अणुओं की संरचना को समझने में।\n*   लेजर, ट्रांजिस्टर (सभी आधुनिक इलेक्ट्रॉनिक्स का आधार), एमआरआई स्कैनर, एलईडी और परमाणु घड़ियों जैसी तकनीकों को विकसित करने में।\n*   क्वांटम कंप्यूटिंग और क्वांटम क्रिप्टोग्राफी जैसे नए क्षेत्रों की खोज करने में।\n\nसंक्षेप में, क्वांटम भौतिकी यह समझने के लिए एक मूलभूत ढाँचा प्रदान करती है कि ब्रह्मांड अपने सबसे बुनियादी स्तर पर कैसे काम करता है, यह लगभग सभी आधुनिक प्रौद्योगिकी और रसायन विज्ञान, पदार्थ विज्ञान (materials science) और यहाँ तक कि ब्रह्मांड विज्ञान (cosmology) की हमारी समझ का भी आधार है।'}
